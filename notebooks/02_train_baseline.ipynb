# %% [markdown]
# # Train Baseline
# Run training using scripts/train_baseline.py and inspect produced artifacts.

# %%
# from owaid.training import run_training
# Keep notebook minimal and re-usable with config + script wrappers.
