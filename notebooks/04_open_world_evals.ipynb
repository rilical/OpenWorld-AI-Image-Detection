# %% [markdown]
# # Open-World Evaluations
# Evaluate VCT2 / RAID / ARIA and generate result summaries.

# %%
# from scripts import eval_vct2, eval_raid, eval_aria
# Load run metrics and render tables/plots.
