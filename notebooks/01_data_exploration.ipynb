# %% [markdown]
# # Data Exploration
#
# Use package loaders and saved configs only. Do not duplicate training or split logic here.

# %%
from pathlib import Path

ROOT = Path.cwd()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent

CFG = ROOT / "configs" / "baseline_clip.yaml"
print("Repo root:", ROOT)
print("Config:", CFG)

# %%
if not CFG.exists():
    print("Missing baseline config. Run from repo root or adjust ROOT.")
else:
    from owaid.utils import load_yaml
    cfg = load_yaml(str(CFG))
    print(cfg["data"])

# %%
print("Next step: once CommunityForensics access is configured, call build_commfor_dataloaders(cfg, run_dir=...) to inspect class balance and split sizes.")
